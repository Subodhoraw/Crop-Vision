# %% [markdown]
# ### week1 - EDA & exploratory data analysis
# eda : explore each section ! suggested commits
# eda : visualize sample images per class
# data_clean : build image preprocessing pipeline
# argument trnasforms
# data- cleans: stratified train/val/test split complete

# %%
import os
import numpy as np 
import matplotlib.pyplot as plt 
import matplotlib.gridspec as gridspec
import seaborn as sns 
from collections import Counter
from pathlib import Path
from PIL import Image 
import warnings 
import cv2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 10
#       8 from PIL import Image
#       9 import warnings
# ---> 10 import cv2
#
# ModuleNotFoundError: No module named 'cv2'
